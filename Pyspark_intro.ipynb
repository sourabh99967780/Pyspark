# %%
sc.stop()

# %%
from pyspark import SparkContext,SparkConf
conf = SparkConf().setAppName("Healthcentre").setMaster("local[2]")
sc = SparkContext.getOrCreate(conf=conf)

# %%
sc
# Out:
# <SparkContext master=local[2] appName=Healthcentre>

# %%
lines1=sc.textFile("file:///home/hadoop/Downloads/POPULATION.csv")

# %%
lines1.take(1000)
# Out:
# [u'id,first_name,last_name,email,gender',
#  u'1,Florella,Elderkin,felderkin0@sphinn.com,Female',
#  u'2,Aldin,Fancutt,afancutt1@dropbox.com,Male',
#  u'3,Stesha,Whelpton,swhelpton2@infoseek.co.jp,Female',
#  u'4,Elane,Bourdon,ebourdon3@free.fr,Female',
#  u'5,Jacynth,Roache,jroache4@issuu.com,Female',
#  u'6,Nessi,Curedell,ncuredell5@webnode.com,Female',
#  u'7,Palm,Dolbey,pdolbey6@dot.gov,Male',
#  u'8,Marcile,Danielsohn,mdanielsohn7@deviantart.com,Female',
#  u'9,Abie,Pettis,apettis8@infoseek.co.jp,Male',
#  u'10,Ralf,Boyan,rboyan9@e-recht24.de,Male',
#  u'11,Gwenette,Meffen,gmeffena@slashdot.org,Female',
#  u'12,Abel,Hattam,ahattamb@wiley.com,Male',
#  u'13,Sayer,Gawne,sgawnec@taobao.com,Male',
#  u'14,Marcellina,Carillo,mcarillod@about.com,Female',
#  u'15,Felice,Imison,fimisone@discovery.com,Male',
#  u'16,Lora,Lysons,llysonsf@timesonline.co.uk,Female',
#  u'17,Lawrence,Pool,lpoolg@infoseek.co.jp,Male',
#  u'18,Leona,Kliche,lklicheh@senate.gov,Female',
# ...

# %%
lines2=sc.textFile("file:///home/hadoop/Downloads/POPULATION.json")

# %%
## we can upload json file
## but it will require '///'
## on the other hand csv require '//'

# %%
lines2.take(1000)
# Out:
# [u'[{"id":1,"first_name":"Frederick","last_name":"Giraldon","email":"fgiraldon0@geocities.jp","gender":"Male"},',
#  u'{"id":2,"first_name":"Marcellus","last_name":"Prisley","email":"mprisley1@bandcamp.com","gender":"Male"},',
#  u'{"id":3,"first_name":"Kaye","last_name":"Moyler","email":"kmoyler2@freewebs.com","gender":"Female"},',
#  u'{"id":4,"first_name":"Katusha","last_name":"Bearman","email":"kbearman3@uiuc.edu","gender":"Female"},',
#  u'{"id":5,"first_name":"Meghan","last_name":"Clinch","email":"mclinch4@cam.ac.uk","gender":"Female"},',
#  u'{"id":6,"first_name":"Zea","last_name":"Earwicker","email":"zearwicker5@eepurl.com","gender":"Female"},',
#  u'{"id":7,"first_name":"Ramona","last_name":"Halfacree","email":"rhalfacree6@ask.com","gender":"Female"},',
#  u'{"id":8,"first_name":"Glendon","last_name":"Reiglar","email":"greiglar7@reuters.com","gender":"Male"},',
#  u'{"id":9,"first_name":"Kathye","last_name":"Mawne","email":"kmawne8@hatena.ne.jp","gender":"Female"},',
# ...
